# %%
### Import Statements
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
iphone=pd.read_csv('iphone_mobile.csv')

# %%
samsung=pd.read_csv('samsung_mobile.csv')

# %%
vivo=pd.read_csv('vivo_mobile.csv')

# %%
honor=pd.read_csv('honor_mobile.csv')

# %%
mi=pd.read_csv('mi_mobile (1).csv')

# %%
asus=pd.read_csv('asus_mobile.csv')

# %%
iphone.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1546972287-467  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 1    1546972055-429  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 2    1546972130-439  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 3    1546972022-423  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 4    1546972146-442  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
#
#                                         product_link  \
# 0  Add to CompareApple iPhone SE (Silver, 32 GB)4...
# 1  ON OFFERAdd to CompareApple iPhone 8 Plus (Sil...
# 2  ON OFFERAdd to CompareApple iPhone X (Silver, ...
# 3  Add to CompareApple iPhone XS Max (Space Grey,...
# 4  Add to CompareApple iPhone 7 (Gold, 128 GB)4.5...
#
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# ...

# %%
iphone['brand']='iphone'

# %%
iphone.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1546972287-467  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 1    1546972055-429  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 2    1546972130-439  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 3    1546972022-423  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
# 4    1546972146-442  https://www.flipkart.com/mobiles/pr?sid=tyy%2F...
#
#                                         product_link  \
# 0  Add to CompareApple iPhone SE (Silver, 32 GB)4...
# 1  ON OFFERAdd to CompareApple iPhone 8 Plus (Sil...
# 2  ON OFFERAdd to CompareApple iPhone X (Silver, ...
# 3  Add to CompareApple iPhone XS Max (Space Grey,...
# 4  Add to CompareApple iPhone 7 (Gold, 128 GB)4.5...
#
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# ...

# %%
mi['brand']='mi'
vivo['brand']='vivo'
asus['brand']='asus'
honor['brand']='honor'
samsung['brand']='samsung'

# %%
iphone=iphone.drop(['web-scraper-order','web-scraper-start-url','product_link'],axis=1)

# %%
iphone.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# 2  https://www.flipkart.com/apple-iphone-x-silver...
# 3  https://www.flipkart.com/apple-iphone-xs-max-s...
# 4  https://www.flipkart.com/apple-iphone-7-gold-1...
#
#                                        name      price     delivery_time  \
# 0           Apple iPhone SE (Silver, 32 GB)    ₹17,890          5-6 days
# 1      Apple iPhone 8 Plus (Silver, 256 GB)    ₹79,999  2 Days, Thursday
# 2           Apple iPhone X (Silver, 256 GB)  ₹1,01,999          6-7 days
# 3  Apple iPhone XS Max (Space Grey, 512 GB)  ₹1,40,000          6-7 days
# 4             Apple iPhone 7 (Gold, 128 GB)    ₹56,900          4-5 days
#
#                                              battery       seller  \
# 0  Apple A9 64-bit processor and Embedded M9 Moti...     CELLMARK
# 1  A11 Bionic Chip with 64-bit Architecture, Neur...  SuperComNet
# ...

# %%
mi=mi.drop(['web-scraper-order','web-scraper-start-url','product_link'],axis=1)
vivo=vivo.drop(['web-scraper-order','web-scraper-start-url','product_link'],axis=1)
honor=honor.drop(['web-scraper-order','web-scraper-start-url','product_link'],axis=1)
samsung=samsung.drop(['web-scraper-order','web-scraper-start-url','product_link'],axis=1)
asus=asus.drop(['web-scraper-order','web-scraper-start-url','product_link'],axis=1)

# %%
honor.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/honor-8/p/itmeuydakfe...
# 1  https://www.flipkart.com/honor-8x-blue-128-gb/...
# 2  https://www.flipkart.com/honor-8-lite-black-64...
# 3  https://www.flipkart.com/honor-holly-2-plus-go...
# 4  https://www.flipkart.com/honor-8-pro-midnight-...
#
#                                                name    price   delivery_time  \
# 0                               Honor 8  (4 GB RAM)  ₹29,999        4-6 days
# 1               Honor 8X (Blue, 128 GB)  (6 GB RAM)  ₹19,490  13 Jan, Sunday
# 2           Honor 8 Lite (Black, 64 GB)  (4 GB RAM)  ₹11,999        4-6 days
# 3      Honor Holly 2 Plus (Gold, 16 GB)  (2 GB RAM)   ₹8,300  2 Days, Friday
# 4  Honor 8 Pro (Midnight Black, 128 GB)  (6 GB RAM)  ₹29,999            null
#
#                    battery          seller seller_rating           Color  \
# 0  3000 Li-Polymer Battery     SuperComNet           4.5   Sapphire Blue
# ...

# %%
mi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 19 columns):
# product_link-href           77 non-null object
# name                        76 non-null object
# price                       77 non-null object
# delivery_time               77 non-null object
# battery                     77 non-null object
# seller                      77 non-null object
# seller_rating               77 non-null object
# Color                       77 non-null object
# ram                         77 non-null object
# rom                         77 non-null object
# warranty                    77 non-null object
# overall_rating              77 non-null object
# camera_rating               77 non-null object
# battery_rating              77 non-null object
# display_rating              77 non-null object
# value_for_money_rating      77 non-null object
# product_review_link         77 non-null object
# product_review_link-href    76 non-null object
# ...

# %%
vivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 19 columns):
# product_link-href           50 non-null object
# name                        50 non-null object
# price                       50 non-null object
# delivery_time               50 non-null object
# battery                     50 non-null object
# seller                      50 non-null object
# seller_rating               50 non-null object
# Color                       50 non-null object
# ram                         50 non-null object
# rom                         50 non-null object
# warranty                    50 non-null object
# overall_rating              50 non-null object
# camera_rating               50 non-null object
# battery_rating              50 non-null object
# display_rating              50 non-null object
# value_for_money_rating      50 non-null object
# product_review_link         50 non-null object
# product_review_link-href    49 non-null object
# ...

# %%
honor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 19 columns):
# product_link-href           67 non-null object
# name                        67 non-null object
# price                       67 non-null object
# delivery_time               67 non-null object
# battery                     67 non-null object
# seller                      67 non-null object
# seller_rating               67 non-null object
# Color                       67 non-null object
# ram                         67 non-null object
# rom                         67 non-null object
# warranty                    67 non-null object
# overall_rating              67 non-null float64
# camera_rating               67 non-null object
# battery_rating              67 non-null object
# display_rating              67 non-null object
# value_for_money_rating      67 non-null object
# product_review_link         67 non-null object
# product_review_link-href    63 non-null object
# ...

# %%
asus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 19 columns):
# product_link-href           102 non-null object
# name                        102 non-null object
# price                       102 non-null object
# delivery_time               102 non-null object
# battery                     102 non-null object
# seller                      102 non-null object
# seller_rating               102 non-null object
# Color                       102 non-null object
# ram                         102 non-null object
# rom                         102 non-null object
# warranty                    102 non-null object
# overall_rating              102 non-null float64
# camera_rating               102 non-null object
# battery_rating              102 non-null object
# display_rating              102 non-null object
# value_for_money_rating      102 non-null object
# product_review_link         102 non-null object
# ...

# %%
samsung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 19 columns):
# product_link-href           240 non-null object
# name                        239 non-null object
# price                       240 non-null object
# delivery_time               240 non-null object
# battery                     240 non-null object
# seller                      240 non-null object
# seller_rating               240 non-null object
# Color                       240 non-null object
# ram                         240 non-null object
# rom                         230 non-null object
# warranty                    240 non-null object
# overall_rating              240 non-null object
# camera_rating               240 non-null object
# battery_rating              240 non-null object
# display_rating              240 non-null object
# value_for_money_rating      240 non-null object
# product_review_link         240 non-null object
# ...

# %%
iphone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 19 columns):
# product_link-href           52 non-null object
# name                        52 non-null object
# price                       52 non-null object
# delivery_time               52 non-null object
# battery                     52 non-null object
# seller                      52 non-null object
# seller_rating               52 non-null object
# Color                       52 non-null object
# ram                         52 non-null object
# rom                         52 non-null object
# warranty                    52 non-null object
# overall_rating              52 non-null float64
# camera_rating               52 non-null object
# battery_rating              52 non-null object
# display_rating              52 non-null object
# value_for_money_rating      52 non-null object
# product_review_link         52 non-null object
# product_review_link-href    52 non-null object
# ...

# %%
iphone=iphone.rename(columns={'product_review_link':'no._of_reviews','product_review_link-href':'review_link'})
vivo=vivo.rename(columns={'product_review_link':'no._of_reviews','product_review_link-href':'review_link'})
honor=honor.rename(columns={'product_review_link':'no._of_reviews','product_review_link-href':'review_link'})
samsung=samsung.rename(columns={'product_review_link':'no._of_reviews','product_review_link-href':'review_link'})
asus=asus.rename(columns={'product_review_link':'no._of_reviews','product_review_link-href':'review_link'})
mi=mi.rename(columns={'product_review_link':'no._of_reviews','product_review_link-href':'review_link'})

# %%
iphone.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# 2  https://www.flipkart.com/apple-iphone-x-silver...
# 3  https://www.flipkart.com/apple-iphone-xs-max-s...
# 4  https://www.flipkart.com/apple-iphone-7-gold-1...
#
#                                        name      price     delivery_time  \
# 0           Apple iPhone SE (Silver, 32 GB)    ₹17,890          5-6 days
# 1      Apple iPhone 8 Plus (Silver, 256 GB)    ₹79,999  2 Days, Thursday
# 2           Apple iPhone X (Silver, 256 GB)  ₹1,01,999          6-7 days
# 3  Apple iPhone XS Max (Space Grey, 512 GB)  ₹1,40,000          6-7 days
# 4             Apple iPhone 7 (Gold, 128 GB)    ₹56,900          4-5 days
#
#                                              battery       seller  \
# 0  Apple A9 64-bit processor and Embedded M9 Moti...     CELLMARK
# 1  A11 Bionic Chip with 64-bit Architecture, Neur...  SuperComNet
# ...

# %%
samsung.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/samsung-galaxy-j6-gol...
# 1  https://www.flipkart.com/samsung-galaxy-s9-plu...
# 2  https://www.flipkart.com/samsung-galaxy-a7-blu...
# 3  https://www.flipkart.com/samsung-galaxy-j7-pro...
# 4  https://www.flipkart.com/samsung-galaxy-core-m...
#
#                                                 name    price   delivery_time  \
# 0        Samsung Galaxy J6 (Gold, 64 GB)  (4 GB RAM)  ₹12,990  11 Jan, Friday
# 1  Samsung Galaxy S9 Plus (Burgundy Red, 128 GB) ...  ₹65,900            null
# 2        Samsung Galaxy A7 (Blue, 64 GB)  (4 GB RAM)  ₹23,990        7-8 days
# 3   Samsung Galaxy J7 Pro (Black, 64 GB)  (3 GB RAM)  ₹18,900        6-7 days
# 4  Samsung Galaxy Core (Metallic Blue, 8 GB)  (1 ...   ₹7,999            null
#
#                     battery          seller seller_rating          Color  \
# 0              3000 Battery   TrueComRetail           4.6           Gold
# ...

# %%
samsung['no._of_reviews'][0][4:7]
# Out:
# '627'

# %%
vivo.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/vivo-v9-gold-64-gb/p/...
# 1  https://www.flipkart.com/vivo-y83-pro-nebula-p...
# 2  https://www.flipkart.com/vivo-y93-starry-black...
# 3  https://www.flipkart.com/vivo-y83-black-32-gb/...
# 4  https://www.flipkart.com/vivo-v7-matte-black-6...
#
#                                               name    price  \
# 0                Vivo V9 (Gold, 64 GB)  (4 GB RAM)  ₹15,990
# 1  Vivo Y83 Pro (Nebula Purple, 64 GB)  (4 GB RAM)  ₹13,990
# 2       Vivo Y93 (Starry Black, 32 GB)  (4 GB RAM)  ₹13,990
# 3              Vivo Y83 (Black, 32 GB)  (4 GB RAM)  ₹13,990
# 4        Vivo V7+ (Matte Black, 64 GB)  (4 GB RAM)  ₹19,990
#
#         delivery_time              battery            seller seller_rating  \
# 0                null  3260 Li-ion Battery              null          null
# 1  Tomorrow, Thursday  3260 Li-ion Battery  Flashtech Retail           4.9
# ...

# %%
honor.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/honor-8/p/itmeuydakfe...
# 1  https://www.flipkart.com/honor-8x-blue-128-gb/...
# 2  https://www.flipkart.com/honor-8-lite-black-64...
# 3  https://www.flipkart.com/honor-holly-2-plus-go...
# 4  https://www.flipkart.com/honor-8-pro-midnight-...
#
#                                                name    price   delivery_time  \
# 0                               Honor 8  (4 GB RAM)  ₹29,999        4-6 days
# 1               Honor 8X (Blue, 128 GB)  (6 GB RAM)  ₹19,490  13 Jan, Sunday
# 2           Honor 8 Lite (Black, 64 GB)  (4 GB RAM)  ₹11,999        4-6 days
# 3      Honor Holly 2 Plus (Gold, 16 GB)  (2 GB RAM)   ₹8,300  2 Days, Friday
# 4  Honor 8 Pro (Midnight Black, 128 GB)  (6 GB RAM)  ₹29,999            null
#
#                    battery          seller seller_rating           Color  \
# 0  3000 Li-Polymer Battery     SuperComNet           4.5   Sapphire Blue
# ...

# %%
asus.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/asus-zenfone-go-black...
# 1  https://www.flipkart.com/asus-zenfone-4-red-8-...
# 2  https://www.flipkart.com/asus-zenfone-4-red-8-...
# 3  https://www.flipkart.com/asus-zenfone-go-5-0-l...
# 4  https://www.flipkart.com/asus-zenfone-5-a501cg...
#
#                                                 name   price delivery_time  \
# 0         Asus Zenfone GO (Black, 16 GB)  (2 GB RAM)  ₹9,000      4-6 days
# 1             Asus Zenfone 4 (Red, 8 GB)  (1 GB RAM)  ₹4,688          null
# 2             Asus Zenfone 4 (Red, 8 GB)  (1 GB RAM)  ₹7,499          null
# 3  Asus Zenfone Go 5.0 LTE 2nd Gen (Red, 16 GB)  ...  ₹5,949          null
# 4     Asus Zenfone 5 A501CG (Gold, 8 GB)  (2 GB RAM)  ₹8,499          null
#
#                 battery          seller seller_rating  Color   ram    rom  \
# 0          3000 Battery   njoysolutions          null  Black  2 GB  16 GB
# ...

# %%
samsung.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/samsung-galaxy-j6-gol...
# 1  https://www.flipkart.com/samsung-galaxy-s9-plu...
# 2  https://www.flipkart.com/samsung-galaxy-a7-blu...
# 3  https://www.flipkart.com/samsung-galaxy-j7-pro...
# 4  https://www.flipkart.com/samsung-galaxy-core-m...
#
#                                                 name    price   delivery_time  \
# 0        Samsung Galaxy J6 (Gold, 64 GB)  (4 GB RAM)  ₹12,990  11 Jan, Friday
# 1  Samsung Galaxy S9 Plus (Burgundy Red, 128 GB) ...  ₹65,900            null
# 2        Samsung Galaxy A7 (Blue, 64 GB)  (4 GB RAM)  ₹23,990        7-8 days
# 3   Samsung Galaxy J7 Pro (Black, 64 GB)  (3 GB RAM)  ₹18,900        6-7 days
# 4  Samsung Galaxy Core (Metallic Blue, 8 GB)  (1 ...   ₹7,999            null
#
#                     battery          seller seller_rating          Color  \
# 0              3000 Battery   TrueComRetail           4.6           Gold
# ...

# %%
iphone.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# 2  https://www.flipkart.com/apple-iphone-x-silver...
# 3  https://www.flipkart.com/apple-iphone-xs-max-s...
# 4  https://www.flipkart.com/apple-iphone-7-gold-1...
#
#                                        name      price     delivery_time  \
# 0           Apple iPhone SE (Silver, 32 GB)    ₹17,890          5-6 days
# 1      Apple iPhone 8 Plus (Silver, 256 GB)    ₹79,999  2 Days, Thursday
# 2           Apple iPhone X (Silver, 256 GB)  ₹1,01,999          6-7 days
# 3  Apple iPhone XS Max (Space Grey, 512 GB)  ₹1,40,000          6-7 days
# 4             Apple iPhone 7 (Gold, 128 GB)    ₹56,900          4-5 days
#
#                                              battery       seller  \
# 0  Apple A9 64-bit processor and Embedded M9 Moti...     CELLMARK
# 1  A11 Bionic Chip with 64-bit Architecture, Neur...  SuperComNet
# ...

# %%
mi.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/redmi-3s-gold-16-gb/p...
# 1  https://www.flipkart.com/mi-4i-grey-32-gb/p/it...
# 2  https://www.flipkart.com/redmi-note-5-pro-gold...
# 3  https://www.flipkart.com/redmi-6-pro-red-32-gb...
# 4  https://www.flipkart.com/redmi-note-6-pro-blue...
#
#                                          name    price   delivery_time  \
# 0          Redmi 3S (Gold, 16 GB)  (2 GB RAM)   ₹6,999            null
# 1             Mi 4i (Grey, 32 GB)  (2 GB RAM)  ₹14,999            null
# 2  Redmi Note 5 Pro (Gold, 64 GB)  (4 GB RAM)  ₹12,999  11 Jan, Friday
# 3        Redmi 6 Pro (Red, 32 GB)  (3 GB RAM)  ₹11,499            null
# 4  Redmi Note 6 Pro (Blue, 64 GB)  (4 GB RAM)  ₹13,999  11 Jan, Friday
#
#                        battery              seller seller_rating Color   ram  \
# 0  4100 Li-Ion Polymer Battery                null          null  Gold  2 GB
# ...

# %%
import re
p = re.compile('All (.*) reviews')
s=honor['no._of_reviews'][8]
print(p.findall(s))
# Out:
# ['19']

# %%
a=[]
for i in mi['no._of_reviews']:
    import re
    p = re.compile('All (.*) reviews')
    a.append(p.findall(i))
    
mi['reviews']=a

# %%
b=[]
for i in vivo['no._of_reviews']:
    import re
    p = re.compile('All (.*) reviews')
    b.append(p.findall(i))
vivo['reviews']=b

# %%
c=[]
for i in asus['no._of_reviews']:
    import re
    p = re.compile('All (.*) reviews')
    c.append(p.findall(i))
asus['reviews']=c

# %%
d=[]
for i in samsung['no._of_reviews']:
    import re
    p = re.compile('All (.*) reviews')
    d.append(p.findall(i))
samsung['reviews']=d

# %%
e=[]
for i in iphone['no._of_reviews']:
    import re
    p = re.compile('All (.*) reviews')
    e.append(p.findall(i))
iphone['reviews']=e

# %%
f=[]
for i in honor['no._of_reviews']:
    import re
    p = re.compile('All (.*) reviews')
    f.append(p.findall(i))
honor['reviews']=f

# %%
honor.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/honor-8/p/itmeuydakfe...
# 1  https://www.flipkart.com/honor-8x-blue-128-gb/...
# 2  https://www.flipkart.com/honor-8-lite-black-64...
# 3  https://www.flipkart.com/honor-holly-2-plus-go...
# 4  https://www.flipkart.com/honor-8-pro-midnight-...
#
#                                                name    price   delivery_time  \
# 0                               Honor 8  (4 GB RAM)  ₹29,999        4-6 days
# 1               Honor 8X (Blue, 128 GB)  (6 GB RAM)  ₹19,490  13 Jan, Sunday
# 2           Honor 8 Lite (Black, 64 GB)  (4 GB RAM)  ₹11,999        4-6 days
# 3      Honor Holly 2 Plus (Gold, 16 GB)  (2 GB RAM)   ₹8,300  2 Days, Friday
# 4  Honor 8 Pro (Midnight Black, 128 GB)  (6 GB RAM)  ₹29,999            null
#
#                    battery          seller seller_rating           Color  \
# 0  3000 Li-Polymer Battery     SuperComNet           4.5   Sapphire Blue
# ...

# %%
asus.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/asus-zenfone-go-black...
# 1  https://www.flipkart.com/asus-zenfone-4-red-8-...
# 2  https://www.flipkart.com/asus-zenfone-4-red-8-...
# 3  https://www.flipkart.com/asus-zenfone-go-5-0-l...
# 4  https://www.flipkart.com/asus-zenfone-5-a501cg...
#
#                                                 name   price delivery_time  \
# 0         Asus Zenfone GO (Black, 16 GB)  (2 GB RAM)  ₹9,000      4-6 days
# 1             Asus Zenfone 4 (Red, 8 GB)  (1 GB RAM)  ₹4,688          null
# 2             Asus Zenfone 4 (Red, 8 GB)  (1 GB RAM)  ₹7,499          null
# 3  Asus Zenfone Go 5.0 LTE 2nd Gen (Red, 16 GB)  ...  ₹5,949          null
# 4     Asus Zenfone 5 A501CG (Gold, 8 GB)  (2 GB RAM)  ₹8,499          null
#
#                 battery          seller seller_rating  Color   ram    rom  \
# 0          3000 Battery   njoysolutions          null  Black  2 GB  16 GB
# ...

# %%
asus=asus.drop('no._of_reviews',axis=1)
honor=honor.drop('no._of_reviews',axis=1)
mi=mi.drop('no._of_reviews',axis=1)
samsung=samsung.drop('no._of_reviews',axis=1)
iphone=iphone.drop('no._of_reviews',axis=1)
vivo=vivo.drop('no._of_reviews',axis=1)

# %%
asus.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/asus-zenfone-go-black...
# 1  https://www.flipkart.com/asus-zenfone-4-red-8-...
# 2  https://www.flipkart.com/asus-zenfone-4-red-8-...
# 3  https://www.flipkart.com/asus-zenfone-go-5-0-l...
# 4  https://www.flipkart.com/asus-zenfone-5-a501cg...
#
#                                                 name   price delivery_time  \
# 0         Asus Zenfone GO (Black, 16 GB)  (2 GB RAM)  ₹9,000      4-6 days
# 1             Asus Zenfone 4 (Red, 8 GB)  (1 GB RAM)  ₹4,688          null
# 2             Asus Zenfone 4 (Red, 8 GB)  (1 GB RAM)  ₹7,499          null
# 3  Asus Zenfone Go 5.0 LTE 2nd Gen (Red, 16 GB)  ...  ₹5,949          null
# 4     Asus Zenfone 5 A501CG (Gold, 8 GB)  (2 GB RAM)  ₹8,499          null
#
#                 battery          seller seller_rating  Color   ram    rom  \
# 0          3000 Battery   njoysolutions          null  Black  2 GB  16 GB
# ...

# %%
honor.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/honor-8/p/itmeuydakfe...
# 1  https://www.flipkart.com/honor-8x-blue-128-gb/...
# 2  https://www.flipkart.com/honor-8-lite-black-64...
# 3  https://www.flipkart.com/honor-holly-2-plus-go...
# 4  https://www.flipkart.com/honor-8-pro-midnight-...
#
#                                                name    price   delivery_time  \
# 0                               Honor 8  (4 GB RAM)  ₹29,999        4-6 days
# 1               Honor 8X (Blue, 128 GB)  (6 GB RAM)  ₹19,490  13 Jan, Sunday
# 2           Honor 8 Lite (Black, 64 GB)  (4 GB RAM)  ₹11,999        4-6 days
# 3      Honor Holly 2 Plus (Gold, 16 GB)  (2 GB RAM)   ₹8,300  2 Days, Friday
# 4  Honor 8 Pro (Midnight Black, 128 GB)  (6 GB RAM)  ₹29,999            null
#
#                    battery          seller seller_rating           Color  \
# 0  3000 Li-Polymer Battery     SuperComNet           4.5   Sapphire Blue
# ...

# %%
asus_review_list=[]
for r in asus['reviews']:
    if(len(r)>0):
        asus_review_list.append(int(r[0]))
    else:
        asus_review_list.append(0)
asus['no._of_reviews']=asus_review_list
asus=asus.drop('reviews',axis=1)

# %%
mi_review_list=[]
for r in mi['reviews']:
    if(len(r)>0):
        mi_review_list.append(int(r[0]))
    else:
        mi_review_list.append(0)
mi['no._of_reviews']=mi_review_list
mi=mi.drop('reviews',axis=1)

# %%
samsung_review_list=[]
for r in samsung['reviews']:
    if(len(r)>0):
        samsung_review_list.append(int(r[0]))
    else:
        samsung_review_list.append(0)
samsung['no._of_reviews']=samsung_review_list
samsung=samsung.drop('reviews',axis=1)

# %%
vivo_review_list=[]
for r in vivo['reviews']:
    if(len(r)>0):
        vivo_review_list.append(int(r[0]))
    else:
        vivo_review_list.append(0)
vivo['no._of_reviews']=vivo_review_list
vivo=vivo.drop('reviews',axis=1)

# %%
iphone_review_list=[]
for r in iphone['reviews']:
    if(len(r)>0):
        iphone_review_list.append(int(r[0]))
    else:
        iphone_review_list.append(0)
iphone['no._of_reviews']=iphone_review_list
iphone=iphone.drop('reviews',axis=1)

# %%
honor.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/honor-8/p/itmeuydakfe...
# 1  https://www.flipkart.com/honor-8x-blue-128-gb/...
# 2  https://www.flipkart.com/honor-8-lite-black-64...
# 3  https://www.flipkart.com/honor-holly-2-plus-go...
# 4  https://www.flipkart.com/honor-8-pro-midnight-...
#
#                                                name    price   delivery_time  \
# 0                               Honor 8  (4 GB RAM)  ₹29,999        4-6 days
# 1               Honor 8X (Blue, 128 GB)  (6 GB RAM)  ₹19,490  13 Jan, Sunday
# 2           Honor 8 Lite (Black, 64 GB)  (4 GB RAM)  ₹11,999        4-6 days
# 3      Honor Holly 2 Plus (Gold, 16 GB)  (2 GB RAM)   ₹8,300  2 Days, Friday
# 4  Honor 8 Pro (Midnight Black, 128 GB)  (6 GB RAM)  ₹29,999            null
#
#                    battery          seller seller_rating           Color  \
# 0  3000 Li-Polymer Battery     SuperComNet           4.5   Sapphire Blue
# ...

# %%
iphone.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# 2  https://www.flipkart.com/apple-iphone-x-silver...
# 3  https://www.flipkart.com/apple-iphone-xs-max-s...
# 4  https://www.flipkart.com/apple-iphone-7-gold-1...
#
#                                        name      price     delivery_time  \
# 0           Apple iPhone SE (Silver, 32 GB)    ₹17,890          5-6 days
# 1      Apple iPhone 8 Plus (Silver, 256 GB)    ₹79,999  2 Days, Thursday
# 2           Apple iPhone X (Silver, 256 GB)  ₹1,01,999          6-7 days
# 3  Apple iPhone XS Max (Space Grey, 512 GB)  ₹1,40,000          6-7 days
# 4             Apple iPhone 7 (Gold, 128 GB)    ₹56,900          4-5 days
#
#                                              battery       seller  \
# 0  Apple A9 64-bit processor and Embedded M9 Moti...     CELLMARK
# 1  A11 Bionic Chip with 64-bit Architecture, Neur...  SuperComNet
# ...

# %%
positive_reviews=[]
negative_reviews=[]
for r in honor['no._of_reviews']:
    positive_reviews.append(np.random.randint(60,100)*10)
negative_reviews=1000-np.array(positive_reviews)
honor['positive_reviews_score']=positive_reviews
honor['negative_reviews_score']=negative_reviews
honor['total_reviews_score']=positive_reviews-negative_reviews

# %%
positive_reviews=[]
negative_reviews=[]
for r in vivo['no._of_reviews']:
    positive_reviews.append(np.random.randint(60,100)*10)
negative_reviews=1000-np.array(positive_reviews)
vivo['positive_reviews_score']=positive_reviews
vivo['negative_reviews_score']=negative_reviews
vivo['total_reviews_score']=positive_reviews-negative_reviews

# %%
positive_reviews=[]
negative_reviews=[]
for r in mi['no._of_reviews']:
    positive_reviews.append(np.random.randint(60,100)*10)
negative_reviews=1000-np.array(positive_reviews)
mi['positive_reviews_score']=positive_reviews
mi['negative_reviews_score']=negative_reviews
mi['total_reviews_score']=positive_reviews-negative_reviews

# %%
positive_reviews=[]
negative_reviews=[]
for r in iphone['no._of_reviews']:
    positive_reviews.append(np.random.randint(60,100)*10)
negative_reviews=1000-np.array(positive_reviews)
iphone['positive_reviews_score']=positive_reviews
iphone['negative_reviews_score']=negative_reviews
iphone['total_reviews_score']=positive_reviews-negative_reviews

# %%
positive_reviews=[]
negative_reviews=[]
for r in samsung['no._of_reviews']:
    positive_reviews.append(np.random.randint(60,100)*10)
negative_reviews=1000-np.array(positive_reviews)
samsung['positive_reviews_score']=positive_reviews
samsung['negative_reviews_score']=negative_reviews
samsung['total_reviews_score']=positive_reviews-negative_reviews

# %%
positive_reviews=[]
negative_reviews=[]
for r in asus['no._of_reviews']:
    positive_reviews.append(np.random.randint(60,100)*10)
negative_reviews=1000-np.array(positive_reviews)
asus['positive_reviews_score']=positive_reviews
asus['negative_reviews_score']=negative_reviews
asus['total_reviews_score']=positive_reviews-negative_reviews

# %%
honor.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/honor-8/p/itmeuydakfe...
# 1  https://www.flipkart.com/honor-8x-blue-128-gb/...
# 2  https://www.flipkart.com/honor-8-lite-black-64...
# 3  https://www.flipkart.com/honor-holly-2-plus-go...
# 4  https://www.flipkart.com/honor-8-pro-midnight-...
#
#                                                name    price   delivery_time  \
# 0                               Honor 8  (4 GB RAM)  ₹29,999        4-6 days
# 1               Honor 8X (Blue, 128 GB)  (6 GB RAM)  ₹19,490  13 Jan, Sunday
# 2           Honor 8 Lite (Black, 64 GB)  (4 GB RAM)  ₹11,999        4-6 days
# 3      Honor Holly 2 Plus (Gold, 16 GB)  (2 GB RAM)   ₹8,300  2 Days, Friday
# 4  Honor 8 Pro (Midnight Black, 128 GB)  (6 GB RAM)  ₹29,999            null
#
#                    battery          seller seller_rating           Color  \
# 0  3000 Li-Polymer Battery     SuperComNet           4.5   Sapphire Blue
# ...

# %%
iphone.head()
# Out:
#                                    product_link-href  \
# 0  https://www.flipkart.com/apple-iphone-se-silve...
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...
# 2  https://www.flipkart.com/apple-iphone-x-silver...
# 3  https://www.flipkart.com/apple-iphone-xs-max-s...
# 4  https://www.flipkart.com/apple-iphone-7-gold-1...
#
#                                        name      price     delivery_time  \
# 0           Apple iPhone SE (Silver, 32 GB)    ₹17,890          5-6 days
# 1      Apple iPhone 8 Plus (Silver, 256 GB)    ₹79,999  2 Days, Thursday
# 2           Apple iPhone X (Silver, 256 GB)  ₹1,01,999          6-7 days
# 3  Apple iPhone XS Max (Space Grey, 512 GB)  ₹1,40,000          6-7 days
# 4             Apple iPhone 7 (Gold, 128 GB)    ₹56,900          4-5 days
#
#                                              battery       seller  \
# 0  Apple A9 64-bit processor and Embedded M9 Moti...     CELLMARK
# 1  A11 Bionic Chip with 64-bit Architecture, Neur...  SuperComNet
# ...

# %%
mobile=pd.concat([honor,vivo,samsung,mi,asus])

# %%
mobile.tail()
# Out:
#                                      product_link-href  \
# 97   https://www.flipkart.com/asus-zenfone-go-4-5-p...
# 98   https://www.flipkart.com/asus-zenfone-go-silve...
# 99   https://www.flipkart.com/asus-zenfone-go-blue-...
# 100  https://www.flipkart.com/asus-zenfone-3-gold-6...
# 101  https://www.flipkart.com/asus-zenfone-2-laser-...
#
#                                                   name    price  \
# 97        Asus Zenfone Go 4.5 (Pink, 8 GB)  (1 GB RAM)   ₹5,299
# 98     Asus Zenfone Go (Silver Blue, 8 GB)  (1 GB RAM)   ₹4,999
# 99           Asus Zenfone Go (Blue, 32 GB)  (2 GB RAM)   ₹7,399
# 100           Asus Zenfone 3 (Gold, 64 GB)  (4 GB RAM)  ₹14,999
# 101  Asus Zenfone 2 Laser ZE550KL (Black, 16 GB)  (...   ₹8,499
#
#       delivery_time                  battery          seller seller_rating  \
# 97             null     1600 Lithium Battery            null          null
# 98             null  2070 Li-Polymer Battery            null          null
# ...

# %% [markdown]
# ## Preparing Data

# %%
y=mobile['name'].values

# %%
y
# Out:
# array(['Honor 8\xa0\xa0(4 GB RAM)',
#        'Honor 8X (Blue, 128 GB)\xa0\xa0(6 GB RAM)',
#        'Honor 8 Lite (Black, 64 GB)\xa0\xa0(4 GB RAM)',
#        'Honor Holly 2 Plus (Gold, 16 GB)\xa0\xa0(2 GB RAM)',
#        'Honor 8 Pro (Midnight Black, 128 GB)\xa0\xa0(6 GB RAM)',
#        'Honor 9N (Robin Egg Blue, 64 GB)\xa0\xa0(4 GB RAM)',
#        'Honor Holly 3 (Gold, 16 GB)\xa0\xa0(2 GB RAM)',
#        'Honor View 10 (Midnight Black, 128 GB)\xa0\xa0(6 GB RAM)',
#        'Honor Play (Navy Blue, 64 GB)\xa0\xa0(6 GB RAM)',
#        'Honor Bee 4G (Black, 8 GB)\xa0\xa0(1 GB RAM)',
#        'Honor Holly 3 (Black, 32 GB)\xa0\xa0(3 GB RAM)',
#        'Honor Bee 2 (Black, 8 GB)\xa0\xa0(1 GB RAM)',
#        'Honor 6 Plus (Black, 32 GB)\xa0\xa0(3 GB RAM)',
#        'Honor 7S (Black, 16 GB)\xa0\xa0(2 GB RAM)',
#        'Honor 8\xa0\xa0(4 GB RAM)',
#        'Honor Bee 4G (Gold, 8 GB)\xa0\xa0(1 GB RAM)',
#        'Honor 7C (Gold, 64 GB)\xa0\xa0(4 GB RAM)',
# ...
